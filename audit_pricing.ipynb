# %% [markdown]
# <a href="https://colab.research.google.com/github/nvshirahatti/audit_price/blob/main/audit_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sys import audit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("drive/MyDrive/Colab Notebooks/audit_price.tsv", sep="\t", header=0, on_bad_lines='skip')
df = df.dropna()

df["Audit Price"] = df['Audit Price'].str.replace(',', '')
df["Audit Price"] = df['Audit Price'].str.replace('$', '')
df["Audit Price"] = df['Audit Price'].astype(float)
df["Building Area"] = df['Building Area'].str.replace(',', '')
df["Building Area"] = df['Building Area'].str.replace('sq ft', '')
df["Building Area"] = df['Building Area'].astype(float)
df['Address'] = df['Jurisdiction']  + " " + df['Address']
from sentence_transformers import SentenceTransformer

model_st = SentenceTransformer('all-MiniLM-L6-v2')
df['Address_Embed'] = df['Address'].apply(lambda x: model_st.encode(x))

cat_cols = ['Customer', 'Audit Level', 'Primary Use Type']
encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

df.head(10)
# Out:
#                                  Address  Building Area  Primary Use Type  \
# 0               LADBS 1020 E. 14th Place        28906.0                75
# 1                 LADBS 5500 W. 83rd St.        39960.0                75
# 2                LADBS 8414 Orion Avenue        76200.0                66
# 3             LADBS 10511 Lindley Avenue        63184.0                66
# 4  LADBS 1150 North Wilmington Boulevard        45188.0                66
# 5       LADBS 1500 East Lomita Boulevard        22000.0                67
# 6             LADBS 561-581 Mateo Street       192947.0                80
# 7              LADBS 705 West 9th Street       263335.0                66
# 8                 LADBS 1400 N Spring St        20419.0                84
# 9                              LADBS 400        38401.0                83
#
#   Jurisdiction  Customer  Audit Level  Audit Price  \
# 0        LADBS       263            2       5200.0
# 1        LADBS       263            2       5900.0
# 2        LADBS       618            2       5550.0
# 3        LADBS       618            2       5000.0
# 4        LADBS       618            2       4759.4
# 5        LADBS       618            2       4000.0
# 6        LADBS       207            2      12000.0
# 7        LADBS       207            2      15000.0
# 8        LADBS        67            2       4000.0
# 9        LADBS       107            2       4450.0
#
#                                        Address_Embed
# 0  [-0.048052236, -0.07521248, -0.081158765, -0.0...
# 1  [0.009525987, -0.057779964, -0.06404873, 0.041...
# 2  [-0.005886083, -0.08458053, -0.07145674, -0.01...
# 3  [-0.045970257, -0.11960202, -0.057233427, -0.0...
# 4  [0.0030122264, -0.06399064, -0.048572104, -0.0...
# 5  [0.043487664, 0.004597899, -0.06364785, -0.008...
# 6  [-0.060470786, -0.1171309, -0.08176497, 0.0256...
# 7  [-0.0054788445, -0.0978474, -0.06343198, -0.02...
# 8  [-0.037544962, -0.069449574, -0.08128121, -0.0...
# 9  [-0.028487759, -0.079983965, -0.11873362, -0.0...

# %%
import joblib
joblib.dump(encoders, "drive/MyDrive/Colab Notebooks/label_encoders.pkl")
# Out:
# ['drive/MyDrive/Colab Notebooks/label_encoders.pkl']

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1yitKoNqS6es7HwCoiLOKoKMuIe8trQ7XLuOB2-e85xs#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1yitKoNqS6es7HwCoiLOKoKMuIe8trQ7XLuOB2-e85xs#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install xgboost
# !pip install torch
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

class CatEmbedDataset(Dataset):
    def __init__(self, df, cat_cols, num_cols, target_col):
        super().__init__()
        self.df = df
        self.cat_cols = cat_cols
        self.num_cols = num_cols
        self.target_col = target_col

        cat_id_cols = [c for c in cat_cols]
        self.X_cat = df[cat_id_cols].values.astype('int64')  # shape: (N, len(cat_cols))
        self.X_num = df[num_cols].values.astype('float32')    # shape: (N, len(num_cols))
        self.y = df[target_col].values.astype('float32')      # shape: (N,)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        return {
            'X_cat': torch.tensor(self.X_cat[idx], dtype=torch.long),
            'X_num': torch.tensor(self.X_num[idx], dtype=torch.float),
            'y': torch.tensor(self.y[idx], dtype=torch.float)
        }

# Example usage:
cat_cols = ['Customer','Primary Use Type']
num_cols = ['Building Area']
target_col = 'Audit Price'

dataset = CatEmbedDataset(df, cat_cols, num_cols, target_col)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

dataset.df.head(10)
# Out:
#                                  Address  Building Area  Primary Use Type  \
# 0               LADBS 1020 E. 14th Place        28906.0                75
# 1                 LADBS 5500 W. 83rd St.        39960.0                75
# 2                LADBS 8414 Orion Avenue        76200.0                66
# 3             LADBS 10511 Lindley Avenue        63184.0                66
# 4  LADBS 1150 North Wilmington Boulevard        45188.0                66
# 5       LADBS 1500 East Lomita Boulevard        22000.0                67
# 6             LADBS 561-581 Mateo Street       192947.0                80
# 7              LADBS 705 West 9th Street       263335.0                66
# 8                 LADBS 1400 N Spring St        20419.0                84
# 9                              LADBS 400        38401.0                83
#
#   Jurisdiction  Customer  Audit Level  Audit Price  \
# 0        LADBS       263            2       5200.0
# 1        LADBS       263            2       5900.0
# 2        LADBS       618            2       5550.0
# 3        LADBS       618            2       5000.0
# 4        LADBS       618            2       4759.4
# 5        LADBS       618            2       4000.0
# 6        LADBS       207            2      12000.0
# 7        LADBS       207            2      15000.0
# 8        LADBS        67            2       4000.0
# 9        LADBS       107            2       4450.0
#
#                                        Address_Embed
# 0  [-0.048052236, -0.07521248, -0.081158765, -0.0...
# 1  [0.009525987, -0.057779964, -0.06404873, 0.041...
# 2  [-0.005886083, -0.08458053, -0.07145674, -0.01...
# 3  [-0.045970257, -0.11960202, -0.057233427, -0.0...
# 4  [0.0030122264, -0.06399064, -0.048572104, -0.0...
# 5  [0.043487664, 0.004597899, -0.06364785, -0.008...
# 6  [-0.060470786, -0.1171309, -0.08176497, 0.0256...
# 7  [-0.0054788445, -0.0978474, -0.06343198, -0.02...
# 8  [-0.037544962, -0.069449574, -0.08128121, -0.0...
# 9  [-0.028487759, -0.079983965, -0.11873362, -0.0...

# %%
class CatEmbeddingMLP(nn.Module):
    def __init__(self, df, cat_cols, embed_dims, num_cols, hidden_dim=16):
        """
        embed_dims: dict specifying embedding dimension per cat column, e.g.
            {'customer': 4, 'primary_use_type': 4}
        """
        super().__init__()
        self.cat_cols = cat_cols
        self.num_cols = num_cols
        self.embeddings = nn.ModuleList()

        # Build embeddings for each cat col
        total_emb_dim = 0
        for c in cat_cols:
            cardinality = df[c].nunique()
            emb_dim = embed_dims.get(c, 4)  # default to 4 if not specified
            emb = nn.Embedding(num_embeddings=cardinality, embedding_dim=emb_dim)
            nn.init.xavier_uniform_(emb.weight)
            self.embeddings.append(emb)
            total_emb_dim += emb_dim

        self.total_emb_dim = total_emb_dim
        self.num_numeric = len(num_cols)

        # Input to MLP is cat_emb + numeric
        input_dim = self.total_emb_dim + self.num_numeric

        self.fc1 = nn.Linear(input_dim, hidden_dim)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.fc2 = nn.Linear(hidden_dim, 1)
        nn.init.xavier_uniform_(self.fc2.weight)

    def forward(self, X_cat, X_num):
        emb_list = []
        for i, emb_layer in enumerate(self.embeddings):
            emb_out = emb_layer(X_cat[:, i])  # shape: (B, embed_dim_i)
            emb_list.append(emb_out)
        cat_emb = torch.cat(emb_list, dim=1)  # (B, total_emb_dim)

        x = torch.cat([cat_emb, X_num], dim=1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x.squeeze(-1)  # shape: (B,)

    def extract_row_embedding(self, X_cat, X_num):
        """
        Returns the final hidden layer (just before output).
        We can use this as the "row embedding" for each sample.
        """
        emb_list = []
        for i, emb_layer in enumerate(self.embeddings):
            emb_out = emb_layer(X_cat[:, i])
            emb_list.append(emb_out)
        cat_emb = torch.cat(emb_list, dim=1)  # (B, total_emb_dim)

        x = torch.cat([cat_emb, X_num], dim=1)
        x = F.relu(self.fc1(x))  # only up to hidden layer
        return x  # shape: (B, hidden_dim)

# %%
embed_dims = {'Customer': 4, 'Primary Use Type': 4}
model_embed = CatEmbeddingMLP(df, cat_cols, embed_dims, num_cols, hidden_dim=16)

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model_embed.parameters(), lr=0.01)

epochs = 20
for epoch in range(epochs):
    model_embed.train()
    total_loss = 0.0

    for batch in dataloader:
        X_cat = batch['X_cat']
        X_num = batch['X_num']
        y_true = batch['y']

        optimizer.zero_grad()
        y_pred = model_embed(X_cat, X_num)
        loss = criterion(y_pred, y_true)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    avg_loss = total_loss/len(dataloader)
    print(f"Epoch {epoch+1}/{epochs}, Loss={avg_loss:.3f}")
# Out:
# Epoch 1/20, Loss=4511.931
# Epoch 2/20, Loss=3581.548
# Epoch 3/20, Loss=3038.602
# Epoch 4/20, Loss=2689.610
# Epoch 5/20, Loss=2346.589
# Epoch 6/20, Loss=2309.653
# Epoch 7/20, Loss=1820.936
# Epoch 8/20, Loss=1875.429
# Epoch 9/20, Loss=1778.830
# Epoch 10/20, Loss=1576.277
# Epoch 11/20, Loss=1475.876
# Epoch 12/20, Loss=1315.283
# Epoch 13/20, Loss=1240.678
# Epoch 14/20, Loss=1150.880
# Epoch 15/20, Loss=1173.077
# Epoch 16/20, Loss=1084.761
# Epoch 17/20, Loss=1076.475
# Epoch 18/20, Loss=1062.421
# Epoch 19/20, Loss=1083.741
# Epoch 20/20, Loss=932.887

# %%
torch.save(model_embed, "drive/MyDrive/Colab Notebooks/embedding_cat_audit")

# %%
def create_row_embeddings(model, dataset):
    """
    For each row in 'dataset', use model.extract_row_embedding()
    to get a row-level vector (the hidden_dim).
    Returns X_emb: shape (N, hidden_dim).
    """
    loader = DataLoader(dataset, batch_size=64, shuffle=False)
    model.eval()

    all_vecs = []
    with torch.no_grad():
        for batch in loader:
            X_cat = batch['X_cat']
            X_num = batch['X_num']
            row_vecs = model.extract_row_embedding(X_cat, X_num)
            all_vecs.append(row_vecs.cpu().numpy())
    X_emb = np.concatenate(all_vecs, axis=0)
    return X_emb

row_emb = create_row_embeddings(model_embed, dataset)
row_emb.shape
# Out:
# (1308, 16)

# %%
# 1) Row embeddings from the MLP
X_mlp_emb = row_emb  # shape (N, hidden_dim=16 in this example)

# 2) Address embeddings
# We stored them in df['addr_emb'] as (384,) arrays
X_addr_emb = np.stack(df['Address_Embed'].values, axis=0)  # shape (N, 384)

# 3) If we also want building_area again, let's extract it:
X_num = df[['Building Area']].values.astype('float32')  # shape (N,1)

# Combine
X_final = np.concatenate([X_mlp_emb, X_addr_emb, X_num], axis=1)
y_final = df['Audit Price'].values.astype('float32')

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.13.1)

# %%
import xgboost as xgb
model_xgb = xgb.XGBRegressor(n_estimators=50, learning_rate=0.1, max_depth = 5, min_child_weight = 5, subsample=0.9, colsample_bytree = 0.9)
model_xgb.fit(X_final, y_final)

preds = model_xgb.predict(X_final)

# evaluate
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error(y_final, preds, )
print(f"RMSE: {rmse}")
# Out:
# RMSE: 739.0711059570312

# %%
print("Predictions vs Actual:")
for p, t in zip(preds, y_final):
    print(f"Pred = {p:.1f}, Actual = {t:.1f}")
# Out:
# Predictions vs Actual:
# Pred = 4799.1, Actual = 5200.0
# Pred = 5702.0, Actual = 5900.0
# Pred = 6038.9, Actual = 5550.0
# Pred = 5702.4, Actual = 5000.0
# Pred = 5094.9, Actual = 4759.4
# Pred = 4619.0, Actual = 4000.0
# Pred = 11465.7, Actual = 12000.0
# Pred = 13236.8, Actual = 15000.0
# Pred = 4677.7, Actual = 4000.0
# Pred = 5098.5, Actual = 4450.0
# Pred = 4725.6, Actual = 4000.0
# Pred = 5332.0, Actual = 6250.0
# Pred = 5126.0, Actual = 5350.0
# Pred = 6292.1, Actual = 5250.0
# Pred = 5594.9, Actual = 4250.0
# Pred = 4714.6, Actual = 4000.0
# Pred = 5559.1, Actual = 6000.0
# Pred = 5076.9, Actual = 4750.0
# Pred = 5197.0, Actual = 5000.0
# Pred = 7159.7, Actual = 6250.0
# Pred = 4771.1, Actual = 4750.0
# Pred = 4519.4, Actual = 4000.0
# Pred = 5003.5, Actual = 5000.0
# Pred = 4667.8, Actual = 4000.0
# Pred = 4754.4, Actual = 5000.0
# Pred = 4737.5, Actual = 5000.0
# Pred = 6276.6, Actual = 6500.0
# Pred = 4976.1, Actual = 5000.0
# Pred = 5709.6, Actual = 5990.0
# Pred = 4773.0, Actual = 4500.0
# Pred = 3177.6, Actual = 2500.0
# Pred = 4851.3, Actual = 5000.0
# Pred = 5006.1, Actual = 5000.0
# Pred = 12222.0, Actual = 15000.0
# Pred = 4708.0, Actual = 5000.0
# Pred = 3000.4, Actual = 2695.0
# Pred = 2767.4, Actual = 2395.0
# Pred = 3706.3, Actual = 3295.0
# Pred = 2696.2, Actual = 2695.0
# Pred = 3683.5, Actual = 3795.0
# Pred = 2450.2, Actual = 1895.0
# Pred = 2598.2, Actual = 2595.0
# Pred = 4813.8, Actual = 4500.0
# Pred = 3841.7, Actual = 4295.0
# Pred = 2496.2, Actual = 2195.0
# Pred = 2316.3, Actual = 1895.0
# Pred = 4768.2, Actual = 4500.0
# Pred = 3376.5, Actual = 2995.0
# Pred = 2702.2, Actual = 2395.0
# Pred = 4641.3, Actual = 5000.0
# Pred = 9807.7, Actual = 12000.0
# Pred = 2212.2, Actual = 1695.0
# Pred = 7267.2, Actual = 7800.0
# Pred = 8199.1, Actual = 7800.0
# Pred = 5935.6, Actual = 5340.0
# Pred = 5786.4, Actual = 5340.0
# Pred = 5511.5, Actual = 5700.0
# Pred = 4820.9, Actual = 4900.0
# Pred = 6577.3, Actual = 6500.0
# Pred = 5486.8, Actual = 5400.0
# Pred = 4821.7, Actual = 4000.0
# Pred = 5533.5, Actual = 4450.0
# Pred = 7171.9, Actual = 7700.0
# Pred = 7159.7, Actual = 6650.0
# Pred = 4771.1, Actual = 4750.0
# Pred = 4731.3, Actual = 4500.0
# Pred = 4732.1, Actual = 4500.0
# Pred = 4773.9, Actual = 4500.0
# Pred = 4889.7, Actual = 4500.0
# Pred = 5109.2, Actual = 5250.0
# Pred = 5113.0, Actual = 5250.0
# Pred = 5429.8, Actual = 5250.0
# Pred = 5462.6, Actual = 6000.0
# Pred = 5429.4, Actual = 6000.0
# Pred = 5513.2, Actual = 6000.0
# Pred = 5967.2, Actual = 6800.0
# Pred = 10148.1, Actual = 12500.0
# Pred = 4637.1, Actual = 4500.0
# Pred = 5242.5, Actual = 5250.0
# Pred = 5534.4, Actual = 5550.0
# Pred = 5283.2, Actual = 5550.0
# Pred = 4252.6, Actual = 4100.0
# Pred = 5042.3, Actual = 5200.0
# Pred = 8968.1, Actual = 7700.0
# Pred = 5217.2, Actual = 5100.0
# Pred = 4843.2, Actual = 4750.0
# Pred = 5859.9, Actual = 6075.0
# Pred = 7631.9, Actual = 8550.0
# Pred = 4994.8, Actual = 4950.0
# Pred = 4263.8, Actual = 4200.0
# Pred = 5672.9, Actual = 6025.0
# Pred = 5839.7, Actual = 5975.0
# Pred = 5655.9, Actual = 5575.0
# Pred = 4712.5, Actual = 4500.0
# Pred = 4677.7, Actual = 4500.0
# Pred = 4406.3, Actual = 4595.0
# Pred = 10879.8, Actual = 11225.0
# Pred = 5711.9, Actual = 5050.0
# Pred = 5028.8, Actual = 5100.0
# Pred = 4398.4, Actual = 4750.0
# Pred = 4747.9, Actual = 4750.0
# Pred = 4901.1, Actual = 5450.0
# Pred = 4718.6, Actual = 5450.0
# Pred = 5315.9, Actual = 5900.0
# Pred = 5807.3, Actual = 6500.0
# Pred = 4792.7, Actual = 4650.0
# Pred = 4940.7, Actual = 4650.0
# Pred = 8833.3, Actual = 9750.0
# Pred = 5113.0, Actual = 4650.0
# Pred = 6238.8, Actual = 5700.0
# Pred = 9200.7, Actual = 9000.0
# Pred = 9762.7, Actual = 9750.0
# Pred = 7817.0, Actual = 7700.0
# Pred = 7394.2, Actual = 7250.0
# Pred = 2980.6, Actual = 2500.0
# Pred = 5704.9, Actual = 6000.0
# Pred = 7819.1, Actual = 7250.0
# Pred = 6139.8, Actual = 6300.0
# Pred = 5087.0, Actual = 6000.0
# Pred = 7247.2, Actual = 7400.0
# Pred = 5312.2, Actual = 5100.0
# Pred = 5291.1, Actual = 5200.0
# Pred = 9739.6, Actual = 10250.0
# Pred = 4753.8, Actual = 4650.0
# Pred = 4726.1, Actual = 4650.0
# Pred = 4741.4, Actual = 4650.0
# Pred = 4745.3, Actual = 4650.0
# Pred = 4716.6, Actual = 4700.0
# Pred = 4755.9, Actual = 4650.0
# Pred = 4783.1, Actual = 4650.0
# Pred = 4737.9, Actual = 4650.0
# Pred = 4793.1, Actual = 4650.0
# Pred = 4789.7, Actual = 4650.0
# Pred = 5001.3, Actual = 5000.0
# Pred = 4898.7, Actual = 5000.0
# Pred = 5103.9, Actual = 5000.0
# Pred = 5118.0, Actual = 5000.0
# Pred = 5123.0, Actual = 5000.0
# Pred = 5122.7, Actual = 5000.0
# Pred = 5356.0, Actual = 5350.0
# Pred = 5537.7, Actual = 5350.0
# Pred = 5427.0, Actual = 5350.0
# Pred = 5342.5, Actual = 5675.0
# Pred = 6747.2, Actual = 6600.0
# Pred = 7153.9, Actual = 7000.0
# Pred = 5683.8, Actual = 5475.0
# Pred = 5045.2, Actual = 5000.0
# Pred = 4733.1, Actual = 4650.0
# Pred = 4826.8, Actual = 4650.0
# Pred = 5289.0, Actual = 5000.0
# Pred = 5508.6, Actual = 5350.0
# Pred = 5969.0, Actual = 6000.0
# Pred = 6111.0, Actual = 6000.0
# Pred = 9508.8, Actual = 9750.0
# Pred = 10666.2, Actual = 11250.0
# Pred = 4797.8, Actual = 4650.0
# Pred = 4843.9, Actual = 4650.0
# Pred = 4906.6, Actual = 5000.0
# Pred = 5898.4, Actual = 5700.0
# Pred = 5901.7, Actual = 5700.0
# Pred = 6188.4, Actual = 6000.0
# Pred = 6275.9, Actual = 7500.0
# Pred = 7266.0, Actual = 7500.0
# Pred = 5370.4, Actual = 5350.0
# Pred = 4906.5, Actual = 5500.0
# Pred = 6933.9, Actual = 6700.0
# Pred = 4734.3, Actual = 4650.0
# Pred = 4725.1, Actual = 4650.0
# Pred = 4771.0, Actual = 4650.0
# Pred = 4761.5, Actual = 4650.0
# Pred = 4753.6, Actual = 4650.0
# Pred = 4754.3, Actual = 4650.0
# Pred = 4781.2, Actual = 4650.0
# Pred = 4761.0, Actual = 4650.0
# Pred = 4801.5, Actual = 4650.0
# Pred = 4761.8, Actual = 4650.0
# Pred = 4965.3, Actual = 4650.0
# Pred = 5172.0, Actual = 5000.0
# Pred = 5108.3, Actual = 5000.0
# Pred = 5144.8, Actual = 5000.0
# Pred = 6135.7, Actual = 6000.0
# Pred = 11358.2, Actual = 12000.0
# Pred = 4724.0, Actual = 4650.0
# Pred = 4750.2, Actual = 4650.0
# Pred = 4765.1, Actual = 4650.0
# Pred = 5509.6, Actual = 4650.0
# Pred = 4908.0, Actual = 5000.0
# Pred = 5041.2, Actual = 5000.0
# Pred = 4891.2, Actual = 5000.0
# Pred = 5142.5, Actual = 5000.0
# Pred = 5293.0, Actual = 5350.0
# Pred = 5671.8, Actual = 5700.0
# Pred = 4501.0, Actual = 4595.0
# Pred = 4612.1, Actual = 2875.0
# Pred = 5015.9, Actual = 5225.0
# Pred = 5268.5, Actual = 5450.0
# Pred = 5101.7, Actual = 5225.0
# Pred = 19216.1, Actual = 19675.0
# Pred = 5290.3, Actual = 5550.0
# Pred = 5033.3, Actual = 5225.0
# Pred = 6466.9, Actual = 6750.0
# Pred = 4712.7, Actual = 4650.0
# Pred = 5212.9, Actual = 5350.0
# Pred = 5695.8, Actual = 5475.0
# Pred = 9582.4, Actual = 9400.0
# Pred = 5456.9, Actual = 4500.0
# Pred = 4796.9, Actual = 5225.0
# Pred = 5298.9, Actual = 5400.0
# Pred = 5668.1, Actual = 6000.0
# Pred = 5296.8, Actual = 5400.0
# Pred = 5310.6, Actual = 5400.0
# Pred = 8418.7, Actual = 8900.0
# Pred = 8863.9, Actual = 8900.0
# Pred = 4783.6, Actual = 4650.0
# Pred = 5067.5, Actual = 5000.0
# Pred = 5041.8, Actual = 5000.0
# Pred = 5245.8, Actual = 5350.0
# Pred = 5468.4, Actual = 5350.0
# Pred = 6088.9, Actual = 6600.0
# Pred = 5927.9, Actual = 6750.0
# Pred = 5023.6, Actual = 5200.0
# Pred = 5025.6, Actual = 5200.0
# Pred = 5494.1, Actual = 5550.0
# Pred = 6164.9, Actual = 6250.0
# Pred = 6133.9, Actual = 6250.0
# Pred = 12662.9, Actual = 13200.0
# Pred = 2296.4, Actual = 2250.0
# Pred = 4772.2, Actual = 5225.0
# Pred = 6348.3, Actual = 6800.0
# Pred = 5652.7, Actual = 5700.0
# Pred = 5174.1, Actual = 5000.0
# Pred = 5027.7, Actual = 4875.0
# Pred = 5080.2, Actual = 5025.0
# Pred = 7057.7, Actual = 6675.0
# Pred = 5603.1, Actual = 5400.0
# Pred = 5098.1, Actual = 5225.0
# Pred = 4892.6, Actual = 5225.0
# Pred = 5135.5, Actual = 5225.0
# Pred = 5737.8, Actual = 6000.0
# Pred = 6044.0, Actual = 6400.0
# Pred = 6973.7, Actual = 7000.0
# Pred = 5200.0, Actual = 5100.0
# Pred = 4760.4, Actual = 4650.0
# Pred = 4837.5, Actual = 5000.0
# Pred = 4698.2, Actual = 4650.0
# Pred = 4730.6, Actual = 4650.0
# Pred = 4949.4, Actual = 4650.0
# Pred = 4990.0, Actual = 4650.0
# Pred = 4774.9, Actual = 4650.0
# Pred = 5227.5, Actual = 5000.0
# Pred = 10705.0, Actual = 12000.0
# Pred = 4610.8, Actual = 4700.0
# Pred = 5075.7, Actual = 5200.0
# Pred = 5245.1, Actual = 5700.0
# Pred = 4737.6, Actual = 4875.0
# Pred = 6186.8, Actual = 6600.0
# Pred = 5182.0, Actual = 5100.0
# Pred = 7515.6, Actual = 7650.0
# Pred = 4735.2, Actual = 4875.0
# Pred = 5065.4, Actual = 5225.0
# Pred = 5817.6, Actual = 5225.0
# Pred = 5995.7, Actual = 5900.0
# Pred = 4822.2, Actual = 4800.0
# Pred = 5611.5, Actual = 5750.0
# Pred = 5280.9, Actual = 5400.0
# Pred = 5119.2, Actual = 5200.0
# Pred = 5226.1, Actual = 5400.0
# Pred = 5705.3, Actual = 6000.0
# Pred = 5841.6, Actual = 6000.0
# Pred = 5364.2, Actual = 5100.0
# Pred = 4741.4, Actual = 4650.0
# Pred = 4771.9, Actual = 4650.0
# Pred = 4766.5, Actual = 4650.0
# Pred = 4896.7, Actual = 4650.0
# Pred = 4931.4, Actual = 4650.0
# Pred = 5005.8, Actual = 4650.0
# Pred = 4911.3, Actual = 4650.0
# Pred = 5144.4, Actual = 5000.0
# Pred = 5209.6, Actual = 5000.0
# Pred = 5452.3, Actual = 5350.0
# Pred = 6073.6, Actual = 6000.0
# Pred = 6875.5, Actual = 6750.0
# Pred = 4753.6, Actual = 4650.0
# Pred = 4779.8, Actual = 4650.0
# Pred = 4766.3, Actual = 4650.0
# Pred = 4824.1, Actual = 4650.0
# Pred = 4823.7, Actual = 4650.0
# Pred = 4910.8, Actual = 4650.0
# Pred = 4880.5, Actual = 4650.0
# Pred = 4920.1, Actual = 4650.0
# Pred = 5096.9, Actual = 5000.0
# Pred = 5130.7, Actual = 5000.0
# Pred = 5264.2, Actual = 5000.0
# Pred = 5840.3, Actual = 5700.0
# Pred = 5991.1, Actual = 6000.0
# Pred = 5662.4, Actual = 6000.0
# Pred = 6250.2, Actual = 6000.0
# Pred = 6284.4, Actual = 6000.0
# Pred = 7505.7, Actual = 7500.0
# Pred = 12658.9, Actual = 13500.0
# Pred = 12603.9, Actual = 13500.0
# Pred = 5028.5, Actual = 5200.0
# Pred = 5071.2, Actual = 5200.0
# Pred = 5108.7, Actual = 5200.0
# Pred = 5727.9, Actual = 5900.0
# Pred = 11411.0, Actual = 11500.0
# Pred = 7565.8, Actual = 7975.0
# Pred = 4925.2, Actual = 5025.0
# Pred = 5027.8, Actual = 5025.0
# Pred = 5722.9, Actual = 5625.0
# Pred = 4714.6, Actual = 4700.0
# Pred = 12962.8, Actual = 13500.0
# Pred = 5124.8, Actual = 6350.0
# Pred = 5095.1, Actual = 5200.0
# Pred = 5034.5, Actual = 3800.0
# Pred = 5136.1, Actual = 5200.0
# Pred = 5062.9, Actual = 5200.0
# Pred = 5897.5, Actual = 6000.0
# Pred = 5638.8, Actual = 6400.0
# Pred = 4742.1, Actual = 4650.0
# Pred = 5015.8, Actual = 5000.0
# Pred = 5264.5, Actual = 5350.0
# Pred = 5664.3, Actual = 5700.0
# Pred = 6042.2, Actual = 6000.0
# Pred = 7573.7, Actual = 7500.0
# Pred = 5030.5, Actual = 5025.0
# Pred = 7840.0, Actual = 7925.0
# Pred = 3369.2, Actual = 2750.0
# Pred = 5131.3, Actual = 5200.0
# Pred = 7532.1, Actual = 7400.0
# Pred = 4743.1, Actual = 4650.0
# Pred = 5016.7, Actual = 4650.0
# Pred = 5094.5, Actual = 5000.0
# Pred = 5495.4, Actual = 5350.0
# Pred = 5565.8, Actual = 5350.0
# Pred = 11437.3, Actual = 12000.0
# Pred = 6135.6, Actual = 6250.0
# Pred = 5195.2, Actual = 5000.0
# Pred = 5127.1, Actual = 5000.0
# Pred = 5134.4, Actual = 5200.0
# Pred = 4779.8, Actual = 4650.0
# Pred = 7485.0, Actual = 7500.0
# Pred = 6684.4, Actual = 7000.0
# Pred = 8274.9, Actual = 7925.0
# Pred = 5078.2, Actual = 4650.0
# Pred = 5761.5, Actual = 5700.0
# Pred = 5214.7, Actual = 5675.0
# Pred = 4093.8, Actual = 3500.0
# Pred = 5550.3, Actual = 5550.0
# Pred = 4630.8, Actual = 5200.0
# Pred = 9332.8, Actual = 8225.0
# Pred = 5011.5, Actual = 4750.0
# Pred = 10054.2, Actual = 10500.0
# Pred = 6222.5, Actual = 5900.0
# Pred = 16649.3, Actual = 17400.0
# Pred = 5826.7, Actual = 5700.0
# Pred = 4900.7, Actual = 4650.0
# Pred = 6729.0, Actual = 6900.0
# Pred = 11001.1, Actual = 12000.0
# Pred = 4809.6, Actual = 5225.0
# Pred = 6152.4, Actual = 6575.0
# Pred = 4872.2, Actual = 4650.0
# Pred = 5306.0, Actual = 5350.0
# Pred = 4788.1, Actual = 4650.0
# Pred = 5095.8, Actual = 4650.0
# Pred = 4706.7, Actual = 4650.0
# Pred = 5277.8, Actual = 5550.0
# Pred = 5565.6, Actual = 5350.0
# Pred = 5328.2, Actual = 5550.0
# Pred = 5073.3, Actual = 5200.0
# Pred = 5116.5, Actual = 4650.0
# Pred = 4763.7, Actual = 4875.0
# Pred = 7149.8, Actual = 7300.0
# Pred = 5677.7, Actual = 5700.0
# Pred = 11201.7, Actual = 11450.0
# Pred = 12673.0, Actual = 13400.0
# Pred = 5243.0, Actual = 5000.0
# Pred = 5029.4, Actual = 5000.0
# Pred = 5809.4, Actual = 5775.0
# Pred = 6242.3, Actual = 6400.0
# Pred = 5410.2, Actual = 5200.0
# Pred = 6778.7, Actual = 6900.0
# Pred = 4811.3, Actual = 4650.0
# Pred = 5121.8, Actual = 5000.0
# Pred = 5090.7, Actual = 5000.0
# Pred = 5569.7, Actual = 5350.0
# Pred = 5767.1, Actual = 5700.0
# Pred = 6721.3, Actual = 6750.0
# Pred = 5738.6, Actual = 5900.0
# Pred = 4751.6, Actual = 4650.0
# Pred = 4899.3, Actual = 4650.0
# Pred = 5082.6, Actual = 5000.0
# Pred = 5168.1, Actual = 5000.0
# Pred = 5367.4, Actual = 5350.0
# Pred = 8188.5, Actual = 8250.0
# Pred = 10729.2, Actual = 10250.0
# Pred = 5095.1, Actual = 5450.0
# Pred = 5464.1, Actual = 5500.0
# Pred = 7169.5, Actual = 6900.0
# Pred = 4975.9, Actual = 4650.0
# Pred = 5117.8, Actual = 5000.0
# Pred = 8173.7, Actual = 7900.0
# Pred = 5153.0, Actual = 5000.0
# Pred = 6112.9, Actual = 4650.0
# Pred = 4768.9, Actual = 4650.0
# Pred = 4704.7, Actual = 4650.0
# Pred = 4783.2, Actual = 4650.0
# Pred = 5552.1, Actual = 5350.0
# Pred = 5732.9, Actual = 5900.0
# Pred = 5368.6, Actual = 5350.0
# Pred = 5075.2, Actual = 5000.0
# Pred = 5896.8, Actual = 5700.0
# Pred = 4993.6, Actual = 5200.0
# Pred = 6725.3, Actual = 6950.0
# Pred = 5767.0, Actual = 5700.0
# Pred = 4715.4, Actual = 4650.0
# Pred = 4724.2, Actual = 4650.0
# Pred = 7647.1, Actual = 8350.0
# Pred = 4766.5, Actual = 4650.0
# Pred = 5179.0, Actual = 4650.0
# Pred = 4630.0, Actual = 4650.0
# Pred = 5127.1, Actual = 5000.0
# Pred = 4853.8, Actual = 5000.0
# Pred = 4980.4, Actual = 5000.0
# Pred = 5306.3, Actual = 5350.0
# Pred = 5590.9, Actual = 5200.0
# Pred = 5289.6, Actual = 5550.0
# Pred = 8553.0, Actual = 8350.0
# Pred = 5133.4, Actual = 5025.0
# Pred = 6055.3, Actual = 6075.0
# Pred = 5815.4, Actual = 5475.0
# Pred = 5447.2, Actual = 5200.0
# Pred = 4813.2, Actual = 5200.0
# Pred = 4865.7, Actual = 4700.0
# Pred = 4813.2, Actual = 4700.0
# Pred = 4703.5, Actual = 4875.0
# Pred = 4904.4, Actual = 4650.0
# Pred = 5150.9, Actual = 5000.0
# Pred = 4816.0, Actual = 5225.0
# Pred = 4794.1, Actual = 4650.0
# Pred = 4945.2, Actual = 5225.0
# Pred = 5135.6, Actual = 5025.0
# Pred = 6420.3, Actual = 6750.0
# Pred = 4832.5, Actual = 4800.0
# Pred = 4759.8, Actual = 4650.0
# Pred = 6673.9, Actual = 5625.0
# Pred = 5754.2, Actual = 6000.0
# Pred = 5266.5, Actual = 5000.0
# Pred = 10541.8, Actual = 10500.0
# Pred = 6034.4, Actual = 6000.0
# Pred = 5145.6, Actual = 5000.0
# Pred = 6130.8, Actual = 6400.0
# Pred = 5257.1, Actual = 5450.0
# Pred = 5151.2, Actual = 5200.0
# Pred = 5327.0, Actual = 5350.0
# Pred = 5643.3, Actual = 5900.0
# Pred = 5277.8, Actual = 5340.0
# Pred = 5041.1, Actual = 5700.0
# Pred = 5651.8, Actual = 5325.0
# Pred = 6684.4, Actual = 7000.0
# Pred = 5905.5, Actual = 5700.0
# Pred = 5976.5, Actual = 5700.0
# Pred = 5390.2, Actual = 5450.0
# Pred = 5479.0, Actual = 5450.0
# Pred = 5695.5, Actual = 5675.0
# Pred = 4774.9, Actual = 4650.0
# Pred = 4971.5, Actual = 5000.0
# Pred = 5079.0, Actual = 5000.0
# Pred = 5065.5, Actual = 5000.0
# Pred = 6015.8, Actual = 6900.0
# Pred = 4659.8, Actual = 4750.0
# Pred = 4773.5, Actual = 4800.0
# Pred = 5973.6, Actual = 7050.0
# Pred = 5572.0, Actual = 5675.0
# Pred = 4846.4, Actual = 4650.0
# Pred = 5228.8, Actual = 5000.0
# Pred = 4756.2, Actual = 4650.0
# Pred = 4760.3, Actual = 4650.0
# Pred = 5085.6, Actual = 5000.0
# Pred = 4966.2, Actual = 5200.0
# Pred = 5438.8, Actual = 5200.0
# Pred = 5810.3, Actual = 6000.0
# Pred = 7017.2, Actual = 6900.0
# Pred = 8336.3, Actual = 7800.0
# Pred = 6280.9, Actual = 6600.0
# Pred = 5702.6, Actual = 6950.0
# Pred = 6731.0, Actual = 5925.0
# Pred = 4791.2, Actual = 4900.0
# Pred = 8656.1, Actual = 9000.0
# Pred = 10305.3, Actual = 8925.0
# Pred = 16033.0, Actual = 16596.2
# Pred = 14024.5, Actual = 14050.0
# Pred = 3374.4, Actual = 2900.0
# Pred = 5280.8, Actual = 5450.0
# Pred = 5355.5, Actual = 5550.0
# Pred = 4759.9, Actual = 4650.0
# Pred = 5220.5, Actual = 5000.0
# Pred = 4710.0, Actual = 4650.0
# Pred = 4767.2, Actual = 4650.0
# Pred = 4794.3, Actual = 4800.0
# Pred = 6502.7, Actual = 6750.0
# Pred = 8080.4, Actual = 8145.0
# Pred = 4833.4, Actual = 5225.0
# Pred = 5742.1, Actual = 5450.0
# Pred = 14250.8, Actual = 14450.0
# Pred = 6650.5, Actual = 6525.0
# Pred = 5413.6, Actual = 5050.0
# Pred = 7146.8, Actual = 7100.0
# Pred = 6128.9, Actual = 6925.0
# Pred = 5527.9, Actual = 5675.0
# Pred = 4493.8, Actual = 4595.0
# Pred = 4773.7, Actual = 4650.0
# Pred = 5147.2, Actual = 5000.0
# Pred = 4589.2, Actual = 4450.0
# Pred = 3950.1, Actual = 3500.0
# Pred = 3382.8, Actual = 3500.0
# Pred = 3528.4, Actual = 3500.0
# Pred = 4440.8, Actual = 4000.0
# Pred = 4342.9, Actual = 4500.0
# Pred = 7714.3, Actual = 8100.0
# Pred = 7532.7, Actual = 8100.0
# Pred = 8407.2, Actual = 8100.0
# Pred = 8269.0, Actual = 8400.0
# Pred = 9412.3, Actual = 9500.0
# Pred = 4918.8, Actual = 4500.0
# Pred = 18343.9, Actual = 19975.0
# Pred = 5474.1, Actual = 5350.0
# Pred = 4671.6, Actual = 4687.5
# Pred = 3858.9, Actual = 3600.0
# Pred = 3539.2, Actual = 3438.0
# Pred = 5579.4, Actual = 5312.5
# Pred = 3822.5, Actual = 3600.0
# Pred = 5659.6, Actual = 5750.0
# Pred = 4770.0, Actual = 4650.0
# Pred = 4763.3, Actual = 4650.0
# Pred = 4704.0, Actual = 4650.0
# Pred = 4933.2, Actual = 5000.0
# Pred = 5107.4, Actual = 5000.0
# Pred = 5096.6, Actual = 5000.0
# Pred = 5168.7, Actual = 5000.0
# Pred = 5151.9, Actual = 5000.0
# Pred = 6907.6, Actual = 6750.0
# Pred = 6607.4, Actual = 7500.0
# Pred = 3606.9, Actual = 3650.0
# Pred = 4825.1, Actual = 4850.0
# Pred = 9936.2, Actual = 9750.0
# Pred = 3230.0, Actual = 3150.0
# Pred = 3904.9, Actual = 3600.0
# Pred = 2972.7, Actual = 3150.0
# Pred = 3684.5, Actual = 3510.0
# Pred = 3405.7, Actual = 3525.0
# Pred = 8075.6, Actual = 8175.0
# Pred = 6203.8, Actual = 6750.0
# Pred = 5106.2, Actual = 5280.0
# Pred = 7157.4, Actual = 7025.0
# Pred = 3435.6, Actual = 3150.0
# Pred = 2534.1, Actual = 3150.0
# Pred = 6964.2, Actual = 6785.0
# Pred = 5111.4, Actual = 5700.0
# Pred = 6563.3, Actual = 7800.0
# Pred = 8204.0, Actual = 7600.0
# Pred = 4991.0, Actual = 5320.0
# Pred = 3814.1, Actual = 4025.0
# Pred = 5639.0, Actual = 5700.0
# Pred = 4934.4, Actual = 4650.0
# Pred = 10947.1, Actual = 11250.0
# Pred = 6784.6, Actual = 6600.0
# Pred = 5819.0, Actual = 5700.0
# Pred = 5793.9, Actual = 5900.0
# Pred = 8462.4, Actual = 8925.0
# Pred = 4218.7, Actual = 4110.0
# Pred = 4086.2, Actual = 4110.0
# Pred = 4146.2, Actual = 4110.0
# Pred = 3128.2, Actual = 0.0
# Pred = 5242.1, Actual = 5025.0
# Pred = 5274.4, Actual = 5175.0
# Pred = 7083.5, Actual = 6225.0
# Pred = 6061.3, Actual = 5625.0
# Pred = 5820.5, Actual = 5475.0
# Pred = 4759.0, Actual = 4650.0
# Pred = 5747.7, Actual = 5700.0
# Pred = 4779.8, Actual = 4650.0
# Pred = 4793.1, Actual = 4650.0
# Pred = 3648.1, Actual = 3850.0
# Pred = 5473.5, Actual = 5175.0
# Pred = 5523.7, Actual = 5325.0
# Pred = 5418.9, Actual = 5175.0
# Pred = 7990.9, Actual = 8275.0
# Pred = 2944.4, Actual = 2635.0
# Pred = 5187.4, Actual = 5600.0
# Pred = 4673.9, Actual = 4650.0
# Pred = 5102.9, Actual = 5000.0
# Pred = 5050.7, Actual = 5000.0
# Pred = 5068.4, Actual = 5000.0
# Pred = 5426.9, Actual = 5350.0
# Pred = 5421.0, Actual = 5450.0
# Pred = 3235.0, Actual = 3150.0
# Pred = 4426.7, Actual = 4450.0
# Pred = 3547.5, Actual = 3150.0
# Pred = 3592.2, Actual = 3150.0
# Pred = 3476.2, Actual = 3850.0
# Pred = 3786.6, Actual = 3650.0
# Pred = 4311.5, Actual = 4110.0
# Pred = 6846.7, Actual = 7050.0
# Pred = 6904.3, Actual = 7050.0
# Pred = 7505.4, Actual = 7800.0
# Pred = 6542.8, Actual = 7050.0
# Pred = 6575.9, Actual = 6675.0
# Pred = 3702.7, Actual = 3650.0
# Pred = 6547.6, Actual = 6750.0
# Pred = 3440.7, Actual = 3650.0
# Pred = 4740.2, Actual = 4650.0
# Pred = 2989.1, Actual = 2875.0
# Pred = 2510.5, Actual = 0.0
# Pred = 2355.7, Actual = 0.0
# Pred = 3967.1, Actual = 3600.0
# Pred = 3093.5, Actual = 2875.0
# Pred = 6045.6, Actual = 6000.0
# Pred = 4841.2, Actual = 4650.0
# Pred = 6342.5, Actual = 5775.0
# Pred = 5145.6, Actual = 5225.0
# Pred = 5220.9, Actual = 6950.0
# Pred = 7062.2, Actual = 7175.0
# Pred = 2996.8, Actual = 2875.0
# Pred = 7537.3, Actual = 7075.0
# Pred = 5254.7, Actual = 5450.0
# Pred = 4734.1, Actual = 4650.0
# Pred = 4770.1, Actual = 4650.0
# Pred = 4567.0, Actual = 4650.0
# Pred = 4766.3, Actual = 4650.0
# Pred = 4729.5, Actual = 4650.0
# Pred = 5147.7, Actual = 5000.0
# Pred = 5104.2, Actual = 5000.0
# Pred = 5399.5, Actual = 5000.0
# Pred = 5100.3, Actual = 5000.0
# Pred = 5496.1, Actual = 5350.0
# Pred = 5391.3, Actual = 5350.0
# Pred = 5871.8, Actual = 6000.0
# Pred = 3036.9, Actual = 2875.0
# Pred = 6808.9, Actual = 6075.0
# Pred = 4157.9, Actual = 4325.0
# Pred = 7488.3, Actual = 7650.0
# Pred = 16236.9, Actual = 14425.0
# Pred = 6718.1, Actual = 6400.0
# Pred = 5490.4, Actual = 5350.0
# Pred = 5409.3, Actual = 4650.0
# Pred = 4455.4, Actual = 4050.0
# Pred = 5354.5, Actual = 5350.0
# Pred = 8650.4, Actual = 9050.0
# Pred = 5425.0, Actual = 5350.0
# Pred = 6518.5, Actual = 6575.0
# Pred = 7526.5, Actual = 6150.0
# Pred = 12667.8, Actual = 12675.0
# Pred = 3368.9, Actual = 3425.0
# Pred = 4297.5, Actual = 4325.0
# Pred = 5234.9, Actual = 5350.0
# Pred = 5174.3, Actual = 4875.0
# Pred = 6591.6, Actual = 6350.0
# Pred = 5862.4, Actual = 6250.0
# Pred = 4840.2, Actual = 4875.0
# Pred = 5633.1, Actual = 5450.0
# Pred = 6595.7, Actual = 6600.0
# Pred = 12161.2, Actual = 12350.0
# Pred = 10443.7, Actual = 10325.0
# Pred = 8694.9, Actual = 9050.0
# Pred = 8917.8, Actual = 9400.0
# Pred = 5056.9, Actual = 5225.0
# Pred = 5340.2, Actual = 5225.0
# Pred = 4760.9, Actual = 4700.0
# Pred = 5158.9, Actual = 6350.0
# Pred = 4729.6, Actual = 4650.0
# Pred = 5836.3, Actual = 5700.0
# Pred = 6669.2, Actual = 5700.0
# Pred = 5593.8, Actual = 5700.0
# Pred = 5798.9, Actual = 5700.0
# Pred = 5890.4, Actual = 5700.0
# Pred = 6509.2, Actual = 6750.0
# Pred = 5655.0, Actual = 5350.0
# Pred = 5201.1, Actual = 5700.0
# Pred = 5138.0, Actual = 5225.0
# Pred = 5833.0, Actual = 5700.0
# Pred = 5882.1, Actual = 5775.0
# Pred = 6017.9, Actual = 5800.0
# Pred = 4791.4, Actual = 4875.0
# Pred = 5702.5, Actual = 5475.0
# Pred = 6795.2, Actual = 7025.0
# Pred = 4713.9, Actual = 4650.0
# Pred = 5475.8, Actual = 5475.0
# Pred = 4797.3, Actual = 4650.0
# Pred = 9307.3, Actual = 9050.0
# Pred = 3600.0, Actual = 3200.0
# Pred = 6105.9, Actual = 6125.0
# Pred = 6968.6, Actual = 7025.0
# Pred = 5425.4, Actual = 5125.0
# Pred = 12133.8, Actual = 11375.0
# Pred = 2961.1, Actual = 2875.0
# Pred = 2903.9, Actual = 2875.0
# Pred = 6476.5, Actual = 6400.0
# Pred = 5791.2, Actual = 5700.0
# Pred = 5748.2, Actual = 5925.0
# Pred = 9327.9, Actual = 9050.0
# Pred = 5079.2, Actual = 5200.0
# Pred = 8210.7, Actual = 8250.0
# Pred = 5407.9, Actual = 5350.0
# Pred = 16135.7, Actual = 15125.0
# Pred = 11283.6, Actual = 12000.0
# Pred = 5940.1, Actual = 5800.0
# Pred = 5189.8, Actual = 5175.0
# Pred = 5150.9, Actual = 5000.0
# Pred = 2331.3, Actual = 0.0
# Pred = 5143.1, Actual = 5200.0
# Pred = 5678.3, Actual = 5900.0
# Pred = 5220.1, Actual = 5000.0
# Pred = 5155.0, Actual = 4650.0
# Pred = 5635.4, Actual = 5350.0
# Pred = 3297.0, Actual = 3200.0
# Pred = 4717.3, Actual = 4650.0
# Pred = 5710.1, Actual = 5700.0
# Pred = 4782.4, Actual = 4650.0
# Pred = 4699.9, Actual = 4650.0
# Pred = 5415.9, Actual = 5350.0
# Pred = 6744.9, Actual = 7025.0
# Pred = 4945.9, Actual = 5025.0
# Pred = 5858.7, Actual = 5280.0
# Pred = 5439.1, Actual = 5350.0
# Pred = 6607.1, Actual = 6900.0
# Pred = 7946.1, Actual = 8250.0
# Pred = 5300.7, Actual = 5175.0
# Pred = 5834.0, Actual = 6000.0
# Pred = 4751.2, Actual = 4700.0
# Pred = 5420.6, Actual = 5350.0
# Pred = 6282.2, Actual = 6075.0
# Pred = 10849.4, Actual = 10325.0
# Pred = 4921.3, Actual = 4875.0
# Pred = 4904.3, Actual = 5350.0
# Pred = 5018.6, Actual = 4650.0
# Pred = 6676.3, Actual = 5351.0
# Pred = 5825.8, Actual = 5900.0
# Pred = 5257.1, Actual = 5352.0
# Pred = 5363.6, Actual = 5350.0
# Pred = 6121.6, Actual = 5353.0
# Pred = 5033.4, Actual = 5225.0
# Pred = 5469.0, Actual = 5354.0
# Pred = 7785.2, Actual = 8675.0
# Pred = 5021.1, Actual = 5025.0
# Pred = 5664.6, Actual = 5625.0
# Pred = 5782.2, Actual = 5355.0
# Pred = 7785.5, Actual = 6675.0
# Pred = 4843.6, Actual = 4875.0
# Pred = 4743.1, Actual = 4875.0
# Pred = 4803.5, Actual = 4875.0
# Pred = 5247.4, Actual = 6350.0
# Pred = 4833.0, Actual = 4875.0
# Pred = 5696.8, Actual = 5775.0
# Pred = 5840.6, Actual = 5775.0
# Pred = 4750.7, Actual = 4650.0
# Pred = 6570.3, Actual = 6575.0
# Pred = 4959.9, Actual = 5500.0
# Pred = 5982.5, Actual = 5175.0
# Pred = 5049.5, Actual = 5000.0
# Pred = 4914.0, Actual = 5000.0
# Pred = 5070.8, Actual = 5000.0
# Pred = 5831.1, Actual = 5775.0
# Pred = 5093.6, Actual = 5000.0
# Pred = 5040.0, Actual = 5000.0
# Pred = 5856.7, Actual = 5700.0
# Pred = 6359.4, Actual = 6750.0
# Pred = 5704.4, Actual = 5700.0
# Pred = 4629.4, Actual = 4650.0
# Pred = 3986.8, Actual = 4025.0
# Pred = 5243.6, Actual = 5200.0
# Pred = 7369.3, Actual = 7265.0
# Pred = 4747.9, Actual = 4650.0
# Pred = 4836.5, Actual = 4650.0
# Pred = 4514.6, Actual = 3150.0
# Pred = 4731.5, Actual = 4650.0
# Pred = 4758.0, Actual = 4650.0
# Pred = 5073.8, Actual = 5000.0
# Pred = 5014.2, Actual = 5000.0
# Pred = 4957.2, Actual = 5000.0
# Pred = 4935.5, Actual = 5000.0
# Pred = 5170.5, Actual = 5000.0
# Pred = 4767.2, Actual = 4650.0
# Pred = 5036.7, Actual = 4650.0
# Pred = 4807.5, Actual = 4650.0
# Pred = 5049.7, Actual = 5000.0
# Pred = 5685.5, Actual = 5675.0
# Pred = 6101.8, Actual = 6125.0
# Pred = 5657.9, Actual = 5700.0
# Pred = 5625.7, Actual = 5875.0
# Pred = 17036.8, Actual = 14950.0
# Pred = 6305.0, Actual = 6075.0
# Pred = 5036.6, Actual = 5000.0
# Pred = 3290.8, Actual = 3200.0
# Pred = 5152.7, Actual = 5050.0
# Pred = 7402.1, Actual = 6675.0
# Pred = 5383.5, Actual = 5550.0
# Pred = 9596.0, Actual = 9400.0
# Pred = 4783.6, Actual = 4700.0
# Pred = 4982.6, Actual = 4650.0
# Pred = 4609.2, Actual = 4650.0
# Pred = 4751.0, Actual = 4650.0
# Pred = 5430.2, Actual = 5350.0
# Pred = 5129.4, Actual = 5200.0
# Pred = 5291.7, Actual = 5450.0
# Pred = 4991.5, Actual = 4650.0
# Pred = 5165.4, Actual = 5000.0
# Pred = 5397.4, Actual = 5350.0
# Pred = 8000.9, Actual = 8250.0
# Pred = 5332.3, Actual = 5750.0
# Pred = 6086.9, Actual = 6350.0
# Pred = 11667.2, Actual = 11325.0
# Pred = 17499.4, Actual = 18300.0
# Pred = 6045.6, Actual = 5900.0
# Pred = 7888.5, Actual = 8250.0
# Pred = 5156.4, Actual = 5200.0
# Pred = 4916.0, Actual = 5450.0
# Pred = 6753.6, Actual = 6925.0
# Pred = 5008.8, Actual = 4850.0
# Pred = 5891.4, Actual = 5900.0
# Pred = 5838.6, Actual = 5900.0
# Pred = 7581.5, Actual = 7650.0
# Pred = 6273.0, Actual = 6350.0
# Pred = 5994.0, Actual = 5700.0
# Pred = 11121.7, Actual = 10400.0
# Pred = 12992.8, Actual = 13500.0
# Pred = 9465.7, Actual = 8475.0
# Pred = 6781.9, Actual = 6800.0
# Pred = 3892.3, Actual = 4110.0
# Pred = 5164.0, Actual = 5115.0
# Pred = 5055.4, Actual = 5115.0
# Pred = 5050.0, Actual = 5115.0
# Pred = 5049.7, Actual = 5115.0
# Pred = 5017.0, Actual = 5115.0
# Pred = 5197.0, Actual = 5115.0
# Pred = 5129.8, Actual = 5115.0
# Pred = 5218.6, Actual = 5500.0
# Pred = 5237.1, Actual = 5500.0
# Pred = 5477.2, Actual = 5500.0
# Pred = 4770.0, Actual = 4650.0
# Pred = 5298.4, Actual = 5350.0
# Pred = 5106.0, Actual = 5200.0
# Pred = 4808.7, Actual = 4775.0
# Pred = 5312.9, Actual = 5550.0
# Pred = 4775.5, Actual = 4650.0
# Pred = 8449.5, Actual = 8975.0
# Pred = 5966.1, Actual = 7645.0
# Pred = 6372.4, Actual = 6750.0
# Pred = 6001.1, Actual = 6250.0
# Pred = 5025.6, Actual = 5350.0
# Pred = 5545.2, Actual = 5200.0
# Pred = 4713.9, Actual = 2650.0
# Pred = 4659.8, Actual = 2650.0
# Pred = 5439.3, Actual = 5550.0
# Pred = 6260.1, Actual = 6250.0
# Pred = 5600.8, Actual = 5450.0
# Pred = 6091.6, Actual = 6600.0
# Pred = 7595.4, Actual = 7300.0
# Pred = 8129.3, Actual = 7925.0
# Pred = 7764.7, Actual = 7300.0
# Pred = 5790.8, Actual = 5700.0
# Pred = 15843.6, Actual = 15425.0
# Pred = 19759.5, Actual = 18550.0
# Pred = 13108.6, Actual = 13600.0
# Pred = 25492.4, Actual = 24400.0
# Pred = 5092.1, Actual = 5725.0
# Pred = 4949.4, Actual = 5050.0
# Pred = 4990.0, Actual = 5050.0
# Pred = 5599.8, Actual = 5675.0
# Pred = 5180.6, Actual = 5200.0
# Pred = 8765.2, Actual = 9575.0
# Pred = 4748.1, Actual = 4650.0
# Pred = 5853.6, Actual = 6000.0
# Pred = 5350.3, Actual = 5125.0
# Pred = 4733.6, Actual = 4650.0
# Pred = 4764.4, Actual = 4650.0
# Pred = 4766.3, Actual = 4650.0
# Pred = 4771.9, Actual = 4650.0
# Pred = 4754.1, Actual = 4650.0
# Pred = 5196.0, Actual = 5000.0
# Pred = 5701.7, Actual = 5350.0
# Pred = 6129.2, Actual = 6000.0
# Pred = 7236.4, Actual = 6750.0
# Pred = 10362.7, Actual = 11250.0
# Pred = 5070.9, Actual = 5200.0
# Pred = 5258.2, Actual = 5550.0
# Pred = 11044.6, Actual = 11775.0
# Pred = 5327.5, Actual = 5700.0
# Pred = 5868.7, Actual = 5700.0
# Pred = 4986.2, Actual = 5000.0
# Pred = 7205.8, Actual = 7500.0
# Pred = 5745.6, Actual = 5900.0
# Pred = 5968.9, Actual = 6250.0
# Pred = 8161.4, Actual = 8000.0
# Pred = 4739.7, Actual = 4650.0
# Pred = 4747.4, Actual = 4650.0
# Pred = 5132.8, Actual = 5000.0
# Pred = 5026.3, Actual = 5450.0
# Pred = 6297.3, Actual = 6350.0
# Pred = 5367.2, Actual = 5550.0
# Pred = 8496.1, Actual = 8350.0
# Pred = 4994.5, Actual = 5000.0
# Pred = 4750.0, Actual = 5000.0
# Pred = 4920.3, Actual = 5000.0
# Pred = 5290.1, Actual = 5350.0
# Pred = 5313.7, Actual = 5350.0
# Pred = 7596.9, Actual = 7500.0
# Pred = 5077.8, Actual = 5200.0
# Pred = 6266.8, Actual = 6350.0
# Pred = 4822.4, Actual = 4875.0
# Pred = 16214.5, Actual = 15775.0
# Pred = 5643.4, Actual = 5775.0
# Pred = 5053.8, Actual = 5200.0
# Pred = 8219.2, Actual = 8200.0
# Pred = 4914.5, Actual = 4650.0
# Pred = 4750.1, Actual = 4650.0
# Pred = 4770.6, Actual = 4650.0
# Pred = 5018.0, Actual = 5000.0
# Pred = 5248.0, Actual = 5000.0
# Pred = 5564.2, Actual = 5350.0
# Pred = 6436.9, Actual = 6750.0
# Pred = 6285.1, Actual = 6750.0
# Pred = 6580.0, Actual = 6750.0
# Pred = 7151.5, Actual = 6750.0
# Pred = 7626.3, Actual = 7500.0
# Pred = 7436.6, Actual = 7500.0
# Pred = 7634.7, Actual = 7500.0
# Pred = 5067.5, Actual = 5250.0
# Pred = 5423.6, Actual = 5525.0
# Pred = 5064.1, Actual = 5200.0
# Pred = 7658.6, Actual = 7925.0
# Pred = 7321.4, Actual = 7400.0
# Pred = 6152.4, Actual = 5700.0
# Pred = 5343.4, Actual = 5550.0
# Pred = 16578.4, Actual = 17775.0
# Pred = 13623.9, Actual = 14025.0
# Pred = 33853.5, Actual = 54900.0
# Pred = 11660.9, Actual = 11250.0
# Pred = 5100.9, Actual = 5075.0
# Pred = 4845.8, Actual = 5000.0
# Pred = 5271.0, Actual = 5350.0
# Pred = 5681.3, Actual = 5700.0
# Pred = 6045.5, Actual = 6000.0
# Pred = 8203.3, Actual = 9000.0
# Pred = 5111.7, Actual = 5175.0
# Pred = 7873.0, Actual = 6675.0
# Pred = 7006.3, Actual = 7300.0
# Pred = 7715.7, Actual = 7650.0
# Pred = 5239.7, Actual = 5450.0
# Pred = 7621.8, Actual = 7600.0
# Pred = 5817.1, Actual = 6250.0
# Pred = 16636.7, Actual = 16550.0
# Pred = 5631.9, Actual = 5900.0
# Pred = 6156.9, Actual = 6250.0
# Pred = 7396.3, Actual = 7300.0
# Pred = 4992.7, Actual = 5025.0
# Pred = 4992.7, Actual = 5025.0
# Pred = 5053.5, Actual = 5025.0
# Pred = 5047.8, Actual = 5025.0
# Pred = 5093.5, Actual = 5025.0
# Pred = 4936.8, Actual = 5025.0
# Pred = 5098.9, Actual = 5025.0
# Pred = 5103.6, Actual = 5025.0
# Pred = 5096.9, Actual = 5025.0
# Pred = 5134.1, Actual = 5025.0
# Pred = 5143.2, Actual = 5025.0
# Pred = 5098.9, Actual = 5025.0
# Pred = 5374.7, Actual = 5425.0
# Pred = 5841.6, Actual = 5900.0
# Pred = 5379.7, Actual = 5425.0
# Pred = 5668.4, Actual = 5425.0
# Pred = 5704.2, Actual = 5800.0
# Pred = 5747.1, Actual = 5800.0
# Pred = 5722.0, Actual = 5800.0
# Pred = 5702.4, Actual = 5800.0
# Pred = 5729.6, Actual = 5800.0
# Pred = 5727.2, Actual = 5800.0
# Pred = 5769.4, Actual = 5800.0
# Pred = 5739.3, Actual = 5800.0
# Pred = 5811.2, Actual = 5800.0
# Pred = 5679.1, Actual = 5800.0
# Pred = 5849.9, Actual = 5800.0
# Pred = 5898.3, Actual = 5800.0
# Pred = 5888.0, Actual = 5800.0
# Pred = 5919.2, Actual = 5800.0
# Pred = 6012.1, Actual = 5800.0
# Pred = 6124.6, Actual = 6150.0
# Pred = 6025.4, Actual = 6150.0
# Pred = 6001.2, Actual = 6150.0
# Pred = 6176.7, Actual = 6150.0
# Pred = 6215.8, Actual = 6600.0
# Pred = 6479.5, Actual = 6500.0
# Pred = 6329.4, Actual = 6500.0
# Pred = 7521.2, Actual = 7500.0
# Pred = 7931.2, Actual = 8250.0
# Pred = 7606.6, Actual = 8250.0
# Pred = 8187.2, Actual = 8250.0
# Pred = 9771.2, Actual = 9750.0
# Pred = 9736.3, Actual = 9750.0
# Pred = 9693.9, Actual = 9750.0
# Pred = 10811.0, Actual = 11250.0
# Pred = 13169.2, Actual = 13500.0
# Pred = 12976.5, Actual = 13500.0
# Pred = 8822.3, Actual = 9575.0
# Pred = 5008.7, Actual = 4925.0
# Pred = 4642.8, Actual = 4650.0
# Pred = 3359.1, Actual = 2150.0
# Pred = 3316.0, Actual = 2225.0
# Pred = 3864.4, Actual = 2300.0
# Pred = 5151.6, Actual = 5450.0
# Pred = 5860.2, Actual = 5925.0
# Pred = 5011.7, Actual = 5675.0
# Pred = 6273.3, Actual = 5900.0
# Pred = 8636.0, Actual = 9575.0
# Pred = 4751.2, Actual = 4850.0
# Pred = 5289.4, Actual = 5400.0
# Pred = 5592.0, Actual = 5700.0
# Pred = 5919.0, Actual = 6000.0
# Pred = 5284.6, Actual = 5350.0
# Pred = 6060.5, Actual = 6250.0
# Pred = 4725.8, Actual = 4650.0
# Pred = 4796.9, Actual = 4650.0
# Pred = 4750.6, Actual = 4650.0
# Pred = 4901.0, Actual = 4650.0
# Pred = 5201.9, Actual = 5000.0
# Pred = 5099.1, Actual = 5000.0
# Pred = 5296.0, Actual = 5350.0
# Pred = 5451.1, Actual = 5700.0
# Pred = 8467.7, Actual = 7500.0
# Pred = 11624.4, Actual = 12000.0
# Pred = 5180.2, Actual = 5350.0
# Pred = 4728.7, Actual = 4650.0
# Pred = 4748.1, Actual = 4825.0
# Pred = 4653.2, Actual = 4650.0
# Pred = 5269.6, Actual = 5350.0
# Pred = 6918.9, Actual = 5550.0
# Pred = 5012.9, Actual = 5225.0
# Pred = 5095.3, Actual = 5200.0
# Pred = 4767.4, Actual = 4875.0
# Pred = 5278.9, Actual = 5775.0
# Pred = 4765.7, Actual = 4650.0
# Pred = 4773.7, Actual = 4650.0
# Pred = 4979.5, Actual = 5000.0
# Pred = 5000.9, Actual = 5000.0
# Pred = 5963.0, Actual = 5350.0
# Pred = 5857.7, Actual = 5700.0
# Pred = 6151.1, Actual = 5625.0
# Pred = 5143.4, Actual = 5675.0
# Pred = 6957.6, Actual = 7025.0
# Pred = 4713.9, Actual = 5000.0
# Pred = 5185.0, Actual = 5350.0
# Pred = 5777.6, Actual = 5700.0
# Pred = 4793.1, Actual = 4650.0
# Pred = 4779.8, Actual = 4650.0
# Pred = 4759.0, Actual = 4650.0
# Pred = 5007.9, Actual = 5000.0
# Pred = 5035.3, Actual = 5000.0
# Pred = 5115.9, Actual = 5000.0
# Pred = 5239.4, Actual = 5350.0
# Pred = 5654.7, Actual = 5350.0
# Pred = 6089.1, Actual = 6000.0
# Pred = 5721.4, Actual = 5700.0
# Pred = 5815.2, Actual = 5900.0
# Pred = 4750.7, Actual = 4650.0
# Pred = 5800.9, Actual = 5700.0
# Pred = 4922.1, Actual = 5000.0
# Pred = 10332.1, Actual = 10500.0
# Pred = 9096.0, Actual = 9575.0
# Pred = 5196.8, Actual = 5475.0
# Pred = 5874.4, Actual = 6250.0
# Pred = 6094.2, Actual = 6250.0
# Pred = 4747.4, Actual = 4650.0
# Pred = 4735.1, Actual = 4650.0
# Pred = 5399.5, Actual = 5350.0
# Pred = 6132.8, Actual = 6000.0
# Pred = 5354.5, Actual = 5350.0
# Pred = 5605.2, Actual = 5625.0
# Pred = 6203.5, Actual = 5925.0
# Pred = 5609.0, Actual = 5475.0
# Pred = 5366.5, Actual = 5700.0
# Pred = 5474.3, Actual = 5350.0
# Pred = 5225.9, Actual = 5525.0
# Pred = 5206.8, Actual = 5525.0
# Pred = 6089.8, Actual = 6425.0
# Pred = 4759.7, Actual = 4650.0
# Pred = 4763.4, Actual = 4650.0
# Pred = 4768.3, Actual = 4650.0
# Pred = 4793.5, Actual = 4650.0
# Pred = 4786.0, Actual = 4650.0
# Pred = 5278.3, Actual = 5350.0
# Pred = 5333.0, Actual = 5350.0
# Pred = 10995.9, Actual = 11250.0
# Pred = 5926.5, Actual = 7950.0
# Pred = 5011.4, Actual = 5200.0
# Pred = 7221.5, Actual = 7300.0
# Pred = 9714.6, Actual = 9400.0
# Pred = 8469.6, Actual = 8350.0
# Pred = 5334.4, Actual = 5675.0
# Pred = 5734.0, Actual = 5675.0
# Pred = 5565.9, Actual = 5675.0
# Pred = 4945.4, Actual = 4650.0
# Pred = 4916.0, Actual = 4650.0
# Pred = 4996.0, Actual = 5000.0
# Pred = 5651.5, Actual = 5350.0
# Pred = 5922.5, Actual = 6000.0
# Pred = 6106.7, Actual = 6000.0
# Pred = 5537.6, Actual = 5675.0
# Pred = 5020.3, Actual = 5450.0
# Pred = 5779.1, Actual = 5675.0
# Pred = 7271.4, Actual = 7400.0
# Pred = 4762.6, Actual = 4650.0
# Pred = 4755.4, Actual = 4650.0
# Pred = 4759.2, Actual = 4650.0
# Pred = 5014.4, Actual = 5000.0
# Pred = 5339.4, Actual = 5350.0
# Pred = 5738.6, Actual = 5350.0
# Pred = 5889.3, Actual = 5700.0
# Pred = 5836.2, Actual = 5700.0
# Pred = 6126.0, Actual = 6000.0
# Pred = 7381.8, Actual = 8250.0
# Pred = 5322.1, Actual = 5550.0
# Pred = 6011.8, Actual = 6250.0
# Pred = 5082.3, Actual = 4875.0
# Pred = 5130.8, Actual = 5325.0
# Pred = 5197.8, Actual = 5475.0
# Pred = 4753.6, Actual = 4650.0
# Pred = 4993.1, Actual = 5000.0
# Pred = 5122.4, Actual = 5000.0
# Pred = 5259.3, Actual = 5350.0
# Pred = 5279.0, Actual = 5350.0
# Pred = 5457.8, Actual = 5350.0
# Pred = 5440.2, Actual = 5350.0
# Pred = 5208.3, Actual = 5350.0
# Pred = 4856.7, Actual = 5700.0
# Pred = 5290.2, Actual = 5350.0
# Pred = 5403.0, Actual = 5350.0
# Pred = 4740.9, Actual = 4650.0
# Pred = 4966.5, Actual = 5000.0
# Pred = 5441.0, Actual = 5350.0
# Pred = 5933.7, Actual = 6600.0
# Pred = 8080.1, Actual = 8000.0
# Pred = 5225.9, Actual = 5525.0
# Pred = 5206.8, Actual = 5525.0
# Pred = 4749.8, Actual = 4650.0
# Pred = 4752.4, Actual = 4650.0
# Pred = 4717.3, Actual = 4650.0
# Pred = 5150.9, Actual = 5000.0
# Pred = 5770.2, Actual = 5700.0
# Pred = 5810.6, Actual = 5700.0
# Pred = 6228.8, Actual = 6000.0
# Pred = 7309.3, Actual = 7500.0
# Pred = 10763.2, Actual = 11250.0
# Pred = 5159.8, Actual = 5475.0
# Pred = 4994.1, Actual = 5450.0
# Pred = 4875.0, Actual = 4650.0
# Pred = 4839.7, Actual = 5000.0
# Pred = 4858.6, Actual = 5000.0
# Pred = 5022.4, Actual = 5000.0
# Pred = 4857.4, Actual = 5000.0
# Pred = 5039.4, Actual = 5000.0
# Pred = 5101.1, Actual = 5000.0
# Pred = 5244.9, Actual = 5000.0
# Pred = 5414.6, Actual = 5350.0
# Pred = 5047.9, Actual = 5350.0
# Pred = 5279.8, Actual = 5350.0
# Pred = 5447.8, Actual = 5350.0
# Pred = 5503.7, Actual = 5350.0
# Pred = 6682.0, Actual = 6750.0
# Pred = 6093.2, Actual = 6000.0
# Pred = 6437.9, Actual = 6750.0
# Pred = 5971.9, Actual = 6075.0
# Pred = 5521.2, Actual = 5175.0
# Pred = 5470.3, Actual = 5500.0
# Pred = 8922.0, Actual = 7125.0
# Pred = 5340.3, Actual = 5550.0
# Pred = 8814.9, Actual = 9575.0
# Pred = 4982.6, Actual = 4650.0
# Pred = 4612.3, Actual = 4650.0
# Pred = 4599.7, Actual = 4650.0
# Pred = 4756.2, Actual = 4650.0
# Pred = 5099.8, Actual = 5000.0
# Pred = 5168.1, Actual = 5350.0
# Pred = 5400.8, Actual = 5350.0
# Pred = 5300.8, Actual = 5350.0
# Pred = 7023.1, Actual = 6900.0
# Pred = 11552.1, Actual = 11775.0
# Pred = 17499.4, Actual = 18300.0
# Pred = 15611.2, Actual = 14050.0
# Pred = 5067.4, Actual = 5000.0
# Pred = 5161.6, Actual = 5000.0
# Pred = 5439.3, Actual = 5350.0
# Pred = 5663.2, Actual = 5800.0
# Pred = 6093.2, Actual = 6000.0
# Pred = 6227.0, Actual = 6750.0
# Pred = 6437.9, Actual = 6750.0
# Pred = 8000.9, Actual = 8250.0
# Pred = 5447.2, Actual = 5550.0
# Pred = 9079.7, Actual = 9050.0
# Pred = 7899.7, Actual = 6250.0
# Pred = 6497.7, Actual = 5675.0
# Pred = 5347.3, Actual = 5550.0
# Pred = 4781.7, Actual = 4875.0
# Pred = 4947.0, Actual = 4875.0
# Pred = 4770.9, Actual = 4875.0
# Pred = 5067.5, Actual = 5250.0
# Pred = 10296.2, Actual = 10500.0
# Pred = 5291.7, Actual = 5450.0
# Pred = 12863.1, Actual = 12550.0
# Pred = 6035.7, Actual = 6100.0
# Pred = 5037.2, Actual = 5225.0
# Pred = 5551.6, Actual = 5450.0
# Pred = 6113.3, Actual = 6125.0
# Pred = 6297.3, Actual = 6125.0
# Pred = 4834.6, Actual = 4650.0
# Pred = 5202.0, Actual = 5350.0
# Pred = 8210.7, Actual = 8875.0
# Pred = 4952.8, Actual = 4650.0
# Pred = 5124.4, Actual = 5000.0
# Pred = 6156.9, Actual = 6250.0
# Pred = 6688.9, Actual = 6950.0
# Pred = 7570.5, Actual = 7300.0
# Pred = 10776.1, Actual = 9800.0
# Pred = 9562.3, Actual = 9950.0
# Pred = 5210.7, Actual = 5475.0
# Pred = 5206.2, Actual = 5475.0
# Pred = 5910.3, Actual = 6950.0
# Pred = 14063.5, Actual = 14350.0
# Pred = 12300.0, Actual = 12550.0
# Pred = 18040.4, Actual = 19825.0
# Pred = 9327.9, Actual = 9050.0
# Pred = 6009.1, Actual = 5700.0
# Pred = 5383.1, Actual = 5350.0
# Pred = 4652.5, Actual = 4650.0
# Pred = 5018.7, Actual = 5000.0
# Pred = 5811.0, Actual = 6250.0
# Pred = 6203.5, Actual = 5925.0
# Pred = 5331.1, Actual = 5550.0
# Pred = 4740.2, Actual = 4875.0
# Pred = 5403.1, Actual = 5350.0
# Pred = 5185.0, Actual = 5350.0
# Pred = 4979.3, Actual = 5075.0
# Pred = 5591.3, Actual = 5450.0
# Pred = 4967.8, Actual = 6750.0
# Pred = 4748.0, Actual = 4650.0
# Pred = 5210.6, Actual = 5000.0
# Pred = 5447.2, Actual = 5350.0
# Pred = 4957.0, Actual = 5000.0
# Pred = 5697.4, Actual = 5700.0
# Pred = 5239.7, Actual = 5450.0
# Pred = 4761.6, Actual = 4650.0
# Pred = 5134.1, Actual = 5000.0
# Pred = 4741.5, Actual = 4650.0
# Pred = 5321.5, Actual = 5475.0
# Pred = 5408.6, Actual = 5475.0
# Pred = 7260.5, Actual = 7175.0
# Pred = 9541.7, Actual = 9475.0
# Pred = 5346.6, Actual = 5350.0
# Pred = 10360.4, Actual = 9575.0
# Pred = 3042.4, Actual = 2875.0
# Pred = 3567.0, Actual = 3325.0
# Pred = 5399.5, Actual = 5350.0
# Pred = 4953.4, Actual = 4650.0
# Pred = 5584.0, Actual = 5325.0
# Pred = 6282.4, Actual = 6775.0
# Pred = 5260.4, Actual = 5475.0
# Pred = 5439.7, Actual = 5475.0
# Pred = 5390.1, Actual = 5475.0
# Pred = 5367.3, Actual = 5475.0
# Pred = 10812.4, Actual = 10500.0
# Pred = 5204.8, Actual = 5350.0
# Pred = 5012.0, Actual = 5055.0
# Pred = 8221.7, Actual = 7995.0
# Pred = 5027.7, Actual = 5025.0
# Pred = 4182.6, Actual = 3855.0
# Pred = 5171.2, Actual = 5025.0
# Pred = 5588.8, Actual = 4190.0
# Pred = 4019.0, Actual = 3835.0
# Pred = 2852.0, Actual = 2835.0
# Pred = 5027.7, Actual = 5055.0
# Pred = 7286.3, Actual = 6960.0
# Pred = 10669.1, Actual = 10115.0
# Pred = 10883.3, Actual = 11308.0
# Pred = 5791.1, Actual = 6065.0
# Pred = 4991.5, Actual = 5055.0
# Pred = 5581.5, Actual = 5565.0
# Pred = 5673.0, Actual = 5565.0
# Pred = 5855.9, Actual = 5810.0
# Pred = 6143.3, Actual = 5810.0
# Pred = 6527.0, Actual = 6065.0
# Pred = 6389.0, Actual = 6510.0
# Pred = 9553.2, Actual = 9660.0
# Pred = 6072.5, Actual = 6425.0
# Pred = 6967.3, Actual = 7745.0
# Pred = 4951.7, Actual = 5055.0
# Pred = 5591.3, Actual = 5710.0
# Pred = 5023.1, Actual = 5055.0
# Pred = 5017.1, Actual = 5055.0
# Pred = 5262.5, Actual = 3170.0
# Pred = 4815.1, Actual = 4850.0
# Pred = 5704.4, Actual = 5700.0
# Pred = 5134.1, Actual = 5000.0
# Pred = 4761.6, Actual = 4650.0
# Pred = 4741.5, Actual = 4650.0
# Pred = 5123.7, Actual = 5055.0
# Pred = 5107.6, Actual = 5055.0
# Pred = 5108.2, Actual = 5055.0
# Pred = 5146.0, Actual = 5055.0
# Pred = 4896.7, Actual = 5055.0

# %%
import joblib
joblib.dump(model_xgb, "drive/MyDrive/Colab Notebooks/final_regressor.pkl")
# Out:
# ['drive/MyDrive/Colab Notebooks/final_regressor.pkl']

# %%
torch.save(model_embed.state_dict(), "drive/MyDrive/Colab Notebooks/embedding_cat_audit.pt")
